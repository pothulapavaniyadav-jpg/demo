# %%
# using python 
# i like python 
# * l*k* pyth*n
s=str(input('enter a sentence'))
v='aeiouAEIOU'
res=''
for i in s:
    if i in v:
        res+='*'
    else:
        res+=i
        print(res)
# Out:
# enter a sentence i like python
# *
# * l
# * l*k
# * l*k*
# * l*k* p
# * l*k* py
# * l*k* pyt
# * l*k* pyth
# * l*k* pyth*n

# %%
#palindaram
a=input('enter a string')
if a==a[::-1]:
    print("string the palindram")
else:
    print("the string is not palindram")
# Out:
# enter a string madam
# string the palindram

# %%
# 1 to 20
# 15-> jackpot number
# 10
#choose the higer number 
#19
#choose the lower number
# 15
# your attempt is 3 times
import random
jackpot=random.randint(1,20)
user_num=int(input('enter the number'))
c=1
while jackpot!=user_num:
    if user_num<jackpot:
        print('choose the higer num')
    else:
        print('choose lower num')
    user_num=int(input('enter the number'))
    c+=1
else:
     print('you won the game and jackpot num is',user_num)
     print('you attemp',c)
# Out:
# enter the number 12
# choose the higer num
# enter the number 6
# choose the higer num
# enter the number 4
# choose the higer num
# enter the number 14
# choose the higer num
# enter the number 15
# choose the higer num
# enter the number 5
# choose the higer num
# enter the number 9
# choose the higer num
# enter the number 16
# choose the higer num
# enter the number 19
# you won the game and jackpot num is 19
# you attemp 9
